# %%
import pandas as pd
import numpy as np

# %%
filepath='/content/Copy of customer_transactions_sample.csv'
data=pd.read_csv(filepath)
data
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#             InvoiceDate  Price  Customer ID         Country
# ...

# %%
data_uk=data[data['Country']=='United Kingdom']
data_uk
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#             InvoiceDate  Price  Customer ID         Country
# ...

# %%
data_uk.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      2928
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    106429
# Country             0
# dtype: int64

# %%
data_uk=data[data['Quantity']>0]
data_uk
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#             InvoiceDate  Price  Customer ID         Country
# ...

# %%
#remove rows where customerID are NA
data_uk.dropna(subset=['Customer ID'],how='all',inplace=True)
print(data_uk.shape)
# Out:
# (407695, 8)
# <ipython-input-7-6891e9d9425d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_uk.dropna(subset=['Customer ID'],how='all',inplace=True)

# %%
data_uk['InvoiceDate']
#2009-12-01 07:45:00
#1        2009-12-01 07:45:00
#2        2009-12-01 07:45:00
#3        2009-12-01 07:45:00
#4        2009-12-01 07:45:00
# Out:
# 0          12/1/2009 7:45
# 1          12/1/2009 7:45
# 2          12/1/2009 7:45
# 3          12/1/2009 7:45
# 4          12/1/2009 7:45
#                ...
# 525456    12/9/2010 20:01
# 525457    12/9/2010 20:01
# 525458    12/9/2010 20:01
# 525459    12/9/2010 20:01
# 525460    12/9/2010 20:01
# Name: InvoiceDate, Length: 407695, dtype: object

# %%
#converting into date format to work easily
data_uk['InvoiceDate'] = pd.to_datetime(data_uk['InvoiceDate'], errors='ignore')
data_uk['InvoiceDate']
# Out:
# <ipython-input-9-0b447991316c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_uk['InvoiceDate'] = pd.to_datetime(data_uk['InvoiceDate'], errors='ignore')
# 0        2009-12-01 07:45:00
# 1        2009-12-01 07:45:00
# 2        2009-12-01 07:45:00
# 3        2009-12-01 07:45:00
# 4        2009-12-01 07:45:00
#                  ...
# 525456   2010-12-09 20:01:00
# 525457   2010-12-09 20:01:00
# 525458   2010-12-09 20:01:00
# 525459   2010-12-09 20:01:00
# 525460   2010-12-09 20:01:00
# Name: InvoiceDate, Length: 407695, dtype: datetime64[ns]

# %%
data_uk['InvoiceDate'].max()
# Out:
# Timestamp('2010-12-09 20:01:00')

# %%
#now to calculate the recency we need to get the dates to know how many days before the transaction was made
import datetime as dt
last=dt.date(2010,12,9)
last
# Out:
# datetime.date(2010, 12, 9)

# %%
#create a new column called date which contains the date of invoice only
data_uk['date'] = pd.DatetimeIndex(data_uk['InvoiceDate']).date
data_uk
# Out:
# <ipython-input-12-e77e38e8bd9e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_uk['date'] = pd.DatetimeIndex(data_uk['InvoiceDate']).date
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# ...

# %%
#we will cluster all over the year
data_uk_year=data_uk[data_uk['InvoiceDate']>= '01-04-2010  09:24:00']

# %%
data_uk_year
# Out:
#        Invoice StockCode                         Description  Quantity  \
# 45228   493410   TEST001             This is a test product.         5
# 45230   493412   TEST001             This is a test product.         5
# 45234   493414     21844                      RETRO SPOT MUG        36
# 45235   493414     21533           RETRO SPOT LARGE MILK JUG        12
# 45236   493414     37508     NEW ENGLAND CERAMIC CAKE SERVER         2
# ...        ...       ...                                 ...       ...
# 525456  538171     22271                FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750        FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751      FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970  PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931              JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country        date
# ...

# %%
#now we have year data and ready to calculate the recency
recency_df=data_uk_year.groupby(by='Customer ID',as_index=False)['date'].max()
recency_df.columns = ['Customer ID','LastPurshaceDate']
recency_df
# Out:
#       Customer ID LastPurshaceDate
# 0         12346.0       2010-06-28
# 1         12347.0       2010-12-07
# 2         12348.0       2010-09-27
# 3         12349.0       2010-10-28
# 4         12351.0       2010-11-29
# ...           ...              ...
# 4196      18283.0       2010-11-22
# 4197      18284.0       2010-10-04
# 4198      18285.0       2010-02-17
# 4199      18286.0       2010-08-20
# 4200      18287.0       2010-11-22
#
# [4201 rows x 2 columns]

# %%
recency_df['recency']=recency_df['LastPurshaceDate'].apply(lambda x: (last-x).days)
recency_df
# Out:
#       Customer ID LastPurshaceDate  recency
# 0         12346.0       2010-06-28      164
# 1         12347.0       2010-12-07        2
# 2         12348.0       2010-09-27       73
# 3         12349.0       2010-10-28       42
# 4         12351.0       2010-11-29       10
# ...           ...              ...      ...
# 4196      18283.0       2010-11-22       17
# 4197      18284.0       2010-10-04       66
# 4198      18285.0       2010-02-17      295
# 4199      18286.0       2010-08-20      111
# 4200      18287.0       2010-11-22       17
#
# [4201 rows x 3 columns]

# %%
#now we will calculate the frequency
#invoice represent transaction of a customer
data_uk_year_copy=data_uk_year
data_uk_year_copy.drop_duplicates(subset=['Customer ID','Invoice'],keep="first",inplace=True)
data_uk_year_copy.head()
# Out:
# <ipython-input-17-70628d70d956>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_uk_year_copy.drop_duplicates(subset=['Customer ID','Invoice'],keep="first",inplace=True)
#       Invoice StockCode                         Description  Quantity  \
# 45228  493410   TEST001             This is a test product.         5
# 45230  493412   TEST001             This is a test product.         5
# 45234  493414     21844                      RETRO SPOT MUG        36
# 45242  493427     82483  WOOD 2 DRAWER CABINET WHITE FINISH         4
# 45260  493428    84563A         PINK & WHITE BREAKFAST TRAY         1
#
#               InvoiceDate  Price  Customer ID         Country        date
# 45228 2010-01-04 09:24:00   4.50      12346.0  United Kingdom  2010-01-04
# ...

# %%
#now we will calculate the frequency
#invoice represent transaction of a customer
freq_df=data_uk_year_copy.groupby(by=['Customer ID'],as_index=False)['Invoice'].count()
freq_df.columns=['Customer ID','Freq']
freq_df
# Out:
#       Customer ID  Freq
# 0         12346.0     6
# 1         12347.0     2
# 2         12348.0     1
# 3         12349.0     3
# 4         12351.0     1
# ...           ...   ...
# 4196      18283.0     6
# 4197      18284.0     1
# 4198      18285.0     1
# 4199      18286.0     1
# 4200      18287.0     4
#
# [4201 rows x 2 columns]

# %%
#now we will calculate the monetary
data_uk['Total price']=data_uk['Quantity']*data_uk['Price']
monetary_df=data_uk.groupby(by=['Customer ID'],as_index=False)['Total price'].sum()
monetary_df.columns=['Customer ID','Monetary']
monetary_df
# Out:
# <ipython-input-19-1d0738a4cbfe>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_uk['Total price']=data_uk['Quantity']*data_uk['Price']
#       Customer ID  Monetary
# 0         12346.0    372.86
# 1         12347.0   1323.32
# 2         12348.0    222.16
# 3         12349.0   2671.14
# 4         12351.0    300.93
# ...           ...       ...
# 4309      18283.0    641.77
# 4310      18284.0    461.68
# 4311      18285.0    427.00
# 4312      18286.0   1296.43
# 4313      18287.0   2345.71
#
# [4314 rows x 2 columns]

# %%
#now we have recency,monetary,frequency
#merging all to apply rfm model
rfm_df=recency_df.merge(freq_df,on='Customer ID')
rfm_df
# Out:
#       Customer ID LastPurshaceDate  recency  Freq
# 0         12346.0       2010-06-28      164     6
# 1         12347.0       2010-12-07        2     2
# 2         12348.0       2010-09-27       73     1
# 3         12349.0       2010-10-28       42     3
# 4         12351.0       2010-11-29       10     1
# ...           ...              ...      ...   ...
# 4196      18283.0       2010-11-22       17     6
# 4197      18284.0       2010-10-04       66     1
# 4198      18285.0       2010-02-17      295     1
# 4199      18286.0       2010-08-20      111     1
# 4200      18287.0       2010-11-22       17     4
#
# [4201 rows x 4 columns]

# %%
rfm_df=rfm_df.merge(monetary_df,on='Customer ID')
#set cutomer id as index
rfm_df.set_index('Customer ID',inplace=True)
rfm_df
# Out:
#             LastPurshaceDate  recency  Freq  Monetary
# Customer ID
# 12346.0           2010-06-28      164     6    372.86
# 12347.0           2010-12-07        2     2   1323.32
# 12348.0           2010-09-27       73     1    222.16
# 12349.0           2010-10-28       42     3   2671.14
# 12351.0           2010-11-29       10     1    300.93
# ...                      ...      ...   ...       ...
# 18283.0           2010-11-22       17     6    641.77
# 18284.0           2010-10-04       66     1    461.68
# 18285.0           2010-02-17      295     1    427.00
# 18286.0           2010-08-20      111     1   1296.43
# 18287.0           2010-11-22       17     4   2345.71
#
# [4201 rows x 4 columns]

# %%
#now we will form rfm model and use quartiles(range 1-4) rather quintiles(range 1-5)
quantiles=rfm_df.quantile(q=[0.25,0.50,0.75])
quantiles
# Out:
#      LastPurshaceDate  recency  Freq  Monetary
# 0.25       2010-08-09     17.0   1.0    316.48
# 0.50       2010-10-21     49.0   2.0    733.70
# 0.75       2010-11-22    122.0   5.0   1771.09

# %%
quantiles.to_dict
# Out:
# <bound method DataFrame.to_dict of      LastPurshaceDate  recency  Freq  Monetary
# 0.25       2010-08-09     17.0   1.0    316.48
# 0.50       2010-10-21     49.0   2.0    733.70
# 0.75       2010-11-22    122.0   5.0   1771.09>

# %%
#for a good customer less recency and high frequency and high monetary
# x is value of recency/monetary/frequency and d is dictionary, p is value of customer
def Rscore(x,p,d):
  if x<=d[p][0.25]:
   return 4
  elif x <= d[p][0.50]:
   return 3
  elif x <=d[p][0.75]:
   return 2
  else:
   return 1
# x is value of recency/monetary/frequency and d is dictionary, p is value of customer
def Fscore(x,p,d):
  if x>=d[p][0.75]:
    return 4
  elif x>=d[p][0.50]:
    return 3
  elif x>=d[p][0.25]:
    return 2
  else:
    return 1

# %%
rfm_segmentation =rfm_df
rfm_segmentation['Rscore']=rfm_segmentation['recency'].apply(Rscore, args=('recency',quantiles))
rfm_segmentation['Fscore']=rfm_segmentation['Monetary'].apply(Fscore,args=('Monetary',quantiles))
rfm_segmentation['Mscore']=rfm_segmentation['Freq'].apply(Fscore,args=('Freq',quantiles))
rfm_segmentation
# Out:
#             LastPurshaceDate  recency  Freq  Monetary  Rscore  Fscore  Mscore
# Customer ID
# 12346.0           2010-06-28      164     6    372.86       1       2       4
# 12347.0           2010-12-07        2     2   1323.32       4       3       3
# 12348.0           2010-09-27       73     1    222.16       2       1       2
# 12349.0           2010-10-28       42     3   2671.14       3       4       3
# 12351.0           2010-11-29       10     1    300.93       4       1       2
# ...                      ...      ...   ...       ...     ...     ...     ...
# 18283.0           2010-11-22       17     6    641.77       4       2       4
# 18284.0           2010-10-04       66     1    461.68       2       2       2
# 18285.0           2010-02-17      295     1    427.00       1       2       2
# 18286.0           2010-08-20      111     1   1296.43       2       3       2
# 18287.0           2010-11-22       17     4   2345.71       4       4       3
#
# ...

# %%
rfm_segmentation['RFM_score']=rfm_segmentation.Rscore.map(str) +rfm_segmentation.Fscore.map(str) + rfm_segmentation.Mscore.map(str)
rfm_segmentation
# Out:
#             LastPurshaceDate  recency  Freq  Monetary  Rscore  Fscore  Mscore  \
# Customer ID
# 12346.0           2010-06-28      164     6    372.86       1       2       4
# 12347.0           2010-12-07        2     2   1323.32       4       3       3
# 12348.0           2010-09-27       73     1    222.16       2       1       2
# 12349.0           2010-10-28       42     3   2671.14       3       4       3
# 12351.0           2010-11-29       10     1    300.93       4       1       2
# ...                      ...      ...   ...       ...     ...     ...     ...
# 18283.0           2010-11-22       17     6    641.77       4       2       4
# 18284.0           2010-10-04       66     1    461.68       2       2       2
# 18285.0           2010-02-17      295     1    427.00       1       2       2
# 18286.0           2010-08-20      111     1   1296.43       2       3       2
# 18287.0           2010-11-22       17     4   2345.71       4       4       3
#
# ...

# %%
#lets find  the our best customer means RFM_score =444
print("Best customer:",rfm_segmentation[rfm_segmentation['RFM_score']=='444'].shape[0])
# Out:
# Best customer: 442

# %%
#now giving the result
print("Best customer:",rfm_segmentation[rfm_segmentation['RFM_score']=='444'].shape[0])
print("Big spenders customer:",rfm_segmentation[rfm_segmentation['Mscore']==4].shape[0])
print("Loyal customer:",rfm_segmentation[rfm_segmentation['Fscore']==4].shape[0])
print("Lost customer:",rfm_segmentation[rfm_segmentation['RFM_score']=='111'].shape[0])
# Out:
# Best customer: 442
# Big spenders customer: 1092
# Loyal customer: 1051
# Lost customer: 0
